# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/Users/jiangwolin/IdeaProjects/scala-test/data/intermediateResults/stayDurationDistribution"
df = pd.read_parquet(path)
cutoff = df.loc[df["range"]<=24].copy()
cutoff['log probability'] = np.log(cutoff['probability'])
sns.regplot(x='range', y='log probability', data=cutoff, order=3)
plt.xscale('log', base=5)
